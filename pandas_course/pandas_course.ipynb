# %%
import pandas as pd
import matplotlib.pyplot as graph
import datetime
from matplotlib import style
import pandas_datareader.data as web

# %%
starting = {'Col_1' : [5,2,4,7,10,32],
            'Col_2' : [7,8,2,1,54,108],
            'Col_3' : [5,4,1,8,-12,36],
            'Name' : ['Scrimmy','Bingus','Grimy','Spingus','Chimmy','Scrimmy'],
            'Col_4' : [8,2,4,9,335,1024],
            'Col_5' : [9,0,3,5,1564,25],
            'Col_6' : [7,7,4,3,17,12]}

df = pd.DataFrame(starting)
df = df.set_index('Name')

# %%
print(df)
# Out:
#          Col_1  Col_2  Col_3  Col_4  Col_5  Col_6
# Name
# Scrimmy      5      7      5      8      9      7
# Bingus       2      8      4      2      0      7
# Grimy        4      2      1      4      3      4
# Spingus      7      1      8      9      5      3
# Chimmy      10     54    -12    335   1564     17
# Scrimmy     32    108     36   1024     25     12

# %%
print(att.head())
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2015-01-02  33.970001  33.590000  33.590000  33.869999  20564000.0  25.446146
# 2015-01-05  33.919998  33.520000  33.869999  33.549999  30429100.0  25.205732
# 2015-01-06  33.810001  33.349998  33.770000  33.599998  29595800.0  25.243294
# 2015-01-07  33.590000  32.730000  33.580002  33.169998  31660000.0  25.273773
# 2015-01-08  33.580002  33.150002  33.240002  33.500000  22799800.0  25.525217

# %%
start = datetime.datetime(2015, 1, 1)
end = datetime.datetime(2020, 3, 17)

goog = web.DataReader('G', 'yahoo', start, end)
att = web.DataReader('T', 'yahoo', start, end)

goog[['High', 'Low']].plot()
att[['High', 'Low']].plot()
graph.legend()
graph.show()

# %%
highs = goog['High'].tolist()
print(highs[-1])
# Out:
# 30.329999923706055
